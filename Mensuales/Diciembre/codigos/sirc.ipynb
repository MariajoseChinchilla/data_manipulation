# %%
import pandas as pd

# %%
#cancelados = pd.read_csv(r"C:\Users\mariajose_chinchilla\Downloads\Clientes Cancelados anticipados (julio-agosto-sept 2024) 1.csv")
cancelados = pd.read_csv("../db/dpis.csv")
cancelados.head(3)
# Out:
#              DPI
# 0  1593679051609
# 1  2324094390111
# 2  2440855521803

# %%
with open("../db/codigos_cancelados.txt", "w") as f:
    for codigo in cancelados["DPI"].unique().tolist():
        f.write(f"'{codigo}',")

# %%
bancos = pd.read_csv("../db/bancos_externos.csv", sep=";")

# %%
import matplotlib.pyplot as plt

bancos = bancos[bancos["nomentidad"]!= "BANCO AZTECA DE GUATEMALA, S. A."]
bancos = bancos.head(4)
plt.figure(figsize=(10,6))
plt.bar(bancos["nomentidad"], bancos["cantidad"], color=["#04a41c", "#e4042b", "#04acac", "#78bd23"])
plt.title("Clientes según si poseen un crédito fiduciario en entidad bancaria")
plt.xticks(rotation=10)
plt.show()
